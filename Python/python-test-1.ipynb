# %% [markdown]
# 已连接到 py-3 (Python 3.13.9)

# %%
a=1

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
for i in range(10)
# Out:
#   Cell In[3], line 1
#     for i in range(10)
#                       ^
# SyntaxError: expected ':'

# %%
for i in range(2, 10, 3):
    print(i)
# Out:
# 2
# 5
# 8

# %%
# %%
for i in range(2, 10, 3):
    print(i)
# Out:
# 2
# 5
# 8
